# %%
from langchain.document_loaders.csv_loader import CSVLoader

# %%
resan_team='/home/diego/projects/fm/DA_fm_data/laliga/teams/rsana/all_attrs.csv'
loader = CSVLoader(file_path=resan_team)

data = loader.load()

# %%
print(data)
# Out:
# [Document(page_content='Player: Kim Christian Høyenhall\nUID: 2000182998.0\nAcc: 10.0\nAgi: 14.0\nPac: 11.0\nWor: 10.0\nJum: 16.0\nFir: 10.0\nDri: 3.0\nCmp: 11.0\nSta: 12.0\nPos: 16.0\nCnt: 15.0\nFre: 7.0\nCor: 2.0\nFin: 1.0\nOtB: 2.0\nPas: 13.0\nTec: 12.0\nAnt: 14.0\nDec: 12.0\nLon: 1.0\nFla: 2.0\nTck: 2.0\nHea: 1.0\nAgg: 7.0\nBra: 8.0\nBal: 14.0\nStr: 10.0\nDet: 10.0\nMar: 2.0\nVis: 9.0\nTea: 7.0\nCro: 3.0\nLdr: 10.0\nNat: 11.0\nL Th: 1.0\nPen: 3.0\nAer: 15.0\nCmd: 13.0\nCom: 13.0\nEcc: 2.0\nHan: 12.0\nKic: 14.0\nPun: 5.0\n1v1: 17.0\nRef: 13.0\nTRO: 7.0\nThr: 13.0\nAge: 23.0', metadata={'source': '/home/diego/projects/fm/DA_fm_data/laliga/teams/rsana/all_attrs.csv', 'row': 0}), Document(page_content='Player: Piotr Jabłoński\nUID: 2000623979.0\nAcc: 15.0\nAgi: 17.0\nPac: 15.0\nWor: 19.0\nJum: 3.0\nFir: 12.0\nDri: 12.0\nCmp: 12.0\nSta: 18.0\nPos: 12.0\nCnt: 13.0\nFre: 4.0\nCor: 6.0\nFin: 8.0\nOtB: 10.0\nPas: 12.0\nTec: 12.0\nAnt: 13.0\nDec: 13.0\nLon: 9.0\nFla: 6.0\nTck: 11.0\nHea: 9
# ...
